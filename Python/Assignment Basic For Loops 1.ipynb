# %%
#Print all integers from 0 to 150. Hint:use a for loop and range
for k in range(0 , 151 , 1):
    print(k)

# %%
#Print all the multiples of 5 from 5 to 1,000
for m in range(5 , 1001 , 5):
    print(m)

# %%
#Print integers 1 to 100. If divisible by 5, print "Coding" instead. If divisible by 10, print "Coding Dojo".
D=1
while D <=1000:
    if D % 5 == 0:
        print("Coding")
    elif D % 10 == 0:
        print("Coding Dojo")

# %%
 #Add odd integers from 0 to 500,000, and print the final sum.
odd1=[]

for i in range(0 , 500001 ,1):
      odd1.append(i)
    
print(odd1)  

def addOddNumbers(odd1):
    total = 0
    for num in odd1:
        if num % 2 == 1:
            total += num
    print(total)

# %%
#Print positive numbers starting at 2018, counting down by fours.

for j in range(2018 , 0 , -4):
    print(j)
# Out:
# 2018
# 2014
# 2010
# 2006
# 2002
# 1998
# 1994
# 1990
# 1986
# 1982
# 1978
# 1974
# 1970
# 1966
# 1962
# 1958
# 1954
# 1950
# 1946
# 1942
# 1938
# 1934
# 1930
# 1926
# 1922
# 1918
# 1914
# 1910
# 1906
# 1902
# 1898
# 1894
# 1890
# 1886
# 1882
# 1878
# 1874
# 1870
# 1866
# 1862
# 1858
# 1854
# 1850
# 1846
# 1842
# 1838
# 1834
# 1830
# 1826
# 1822
# 1818
# 1814
# 1810
# 1806
# 1802
# 1798
# 1794
# 1790
# 1786
# 1782
# 1778
# 1774
# 1770
# 1766
# 1762
# 1758
# 1754
# 1750
# 1746
# 1742
# 1738
# 1734
# 1730
# 1726
# 1722
# 1718
# 1714
# 1710
# 1706
# 1702
# 1698
# 1694
# 1690
# 1686
# 1682
# 1678
# 1674
# 1670
# 1666
# 1662
# 1658
# 1654
# 1650
# 1646
# 1642
# 1638
# 1634
# 1630
# 1626
# 1622
# 1618
# 1614
# 1610
# 1606
# 1602
# 1598
# 1594
# 1590
# 1586
# 1582
# 1578
# 1574
# 1570
# 1566
# 1562
# 1558
# 1554
# 1550
# 1546
# 1542
# 1538
# 1534
# 1530
# 1526
# 1522
# 1518
# 1514
# 1510
# 1506
# 1502
# 1498
# 1494
# 1490
# 1486
# 1482
# 1478
# 1474
# 1470
# 1466
# 1462
# 1458
# 1454
# ...

# %%
#Set three variables: lowNum, highNum, mult. Starting at lowNum and going through highNum,
#print only the integers that are a multiple of mult. 
#For example, if lowNum=2, highNum=9, and mult=3, the loop should print 3, 6, 9 (on successive lines)

lowNum=2
highNum=20
mult=4

number=[]
for S in range(lowNum , highNum , mult):
    number.append(S)

print(number)
# Out:
# [2, 6, 10, 14, 18]
