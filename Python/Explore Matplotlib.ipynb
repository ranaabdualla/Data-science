# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data = {'apple': 10, 'orange': 15, 'lemon': 5, 'lime': 20}
names = list(data.keys())
values = list(data.values())

fig, axs = plt.subplots(1, 3, figsize=(9, 3), sharey=True)
axs[0].bar(names, values)
axs[1].scatter(names, values)
axs[2].plot(names, values)
fig.suptitle('Categorical Plotting')
# Out:
# Text(0.5, 0.98, 'Categorical Plotting')

# %% [markdown]
# # Scatter plot:

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(x, y , c='#00FF00')
plt.show()

# %%
#scatter plot
N = 500
x = np.random.rand(100)
y = np.random.rand(100)
area = np.pi*3
plt.scatter(x, y, s=area, c='#E9967A')
plt.title('Random numbers between 0 to 100')
plt.show()

# %%
x =np.random.rand(100)
y = np.random.rand(100)
colors = np.random.rand(100)
sizes = 1000 * rng.rand(100)
plt.title('Random numbers between 0 to 100')
plt.scatter(x, y, c=colors, s=sizes )
plt.colorbar();

# %% [markdown]
# # Line plot:

# %%
#line plot
x = np.arange(0,4)
y = np.cos(x)
plt.plot(x, y , c='#E9967A')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, c='#E9967A' , linestyle = 'dotted')
plt.show()

# %%
boys = ["like it", "not like it", "like it", "like it", "not like it", "like it"]
girls = ["not like it", "like it", "like it", "not like it", "like it", "like it"]
hobbies = ["football", "makeup", "dance", "Basketball", "styling", "swim"]

fig, ax = plt.subplots()
ax.plot(hobbies, boys, label="Boys" , c='b')
ax.plot(hobbies, girls, label="Girls" , c='#FF1493')
ax.legend()

plt.show()

# %% [markdown]
# # Bar plot:

# %%
figure = plt.figure()
ax = figure.add_axes([0,0,1,1])
weather = ['Cloudy', 'Rainy', 'Sunny', 'storm', 'windy']
temp = [23,17,35,29,12]
ax.bar(weather,temp ,  color = '#E9967A', width = 0.50)
plt.show()

# %%
groups = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
men_std = [2, 3, 4, 1, 2]

women_means = [25, 32, 34, 20, 25]
women_std = [3, 5, 2, 3, 3]
      
fig, ax = plt.subplots()
ax.bar(groups, men_means, width = 0.50, yerr=men_std, label='Men' , color='#87CEFA')
ax.bar(groups, women_means, width = 0.50 , yerr=women_std, bottom=men_means, label='Women' ,  color = '#E9967A')

ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %%
x = np.arange(len(labels))  

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width = 0.35 , label='Men',  color='#87CEFA')
rects2 = ax.bar(x + width/2, women_means, width = 0.35 , label='Women',  color = '#E9967A')


ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(groups)
ax.legend()
plt.show()
